# %% [markdown]
# # Zillow Prize: Zillow’s Home Value Prediction (Zestimate)
# The goal for the notebook is predicting whether the house price is above or below median value using ann.
#
# Description of notebook: The first part of the notebook is preparing the data for the model. The second part is regarding setting up the neural network with set hyperparameters, training the model and visualizing the results. And lastly, the third part is hypertuning the model to see if the model will perform better with different hyperparameters.

# %% [markdown]
# # 1. Processing the data

# %% [markdown]
# ## 1.1. Importing needed imports

# %%
import pandas as pd

# %% [markdown]
# ## 1.2. Retrieving the data
# Data explanation can be found below for each column:
# - Lot Area (in sq ft)
# - Overall Quality (scale from 1 to 10)
# - Overall Condition (scale from 1 to 10)
# - Total Basement Area (in sq ft)
# - Number of Full Bathrooms
# - Number of Half Bathrooms
# - Number of Bedrooms above ground
# - Total Number of Rooms above ground
# - Number of Fireplaces
# - Garage Area (in sq ft)
#
# The last columnn of the dataset is what we would like to predict: AboveMedianPrice.
# For example: Is the house price above the median or not? (1 for yes and 2 for no)

# %%
# Retrieving the data
df = pd.read_csv('housepricedata.csv')

# %%
df.head()
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %%
df['AboveMedianPrice'].value_counts()
# Out:
# 0    732
# 1    728
# Name: AboveMedianPrice, dtype: int64

# %% [markdown]
# ## 1.3. Converting the data for our machine to process
# we will be converting the dataframe to an array for the machine to be able to process the data.

# %%
dataset = df.values
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %% [markdown]
# ## 1.4. Splitting the features and prediction data
# In this section we will be splitting the data into the input and output data (X & Y).

# %%
X = dataset[:, 0:10]

# %%
Y = dataset[:, -1]

# %% [markdown]
# ## 1.5. Scaling the feautres
# In this section we will be scaling the input data to have similiar input value. For example not having one input being over 1000 and another input is in a range of 5.
# Due to the amount being so big, will make it difficault for the initialization of the neural network.

# %% [markdown]
# ### 1.5.1. Importing needed imports

# %%
from sklearn import preprocessing

# %% [markdown]
# ### 1.5.2. Scaling the data
# We will be using the min-max scaler which scales the input data so that the input features are between the values 0 and 1. Scaling down to values between 0 & 1 will help aid the training of the neural network.

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %% [markdown]
# ## 1.6. Splitting the data into a train, test & validation sets

# %% [markdown]
# ### 1.6.1. Importing needed imports

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 1.6.2. Splitting the data

# %%
# 70% will be training data
# 30% will be validation and testing data
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %% [markdown]
# Now we will be splitting the test and validation data

# %%
# we will be splitting the data equally here between the test and validation data
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %% [markdown]
# Below we can see the shapes for each data section

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %% [markdown]
# # 2. Building & Training the Neural Network

# %% [markdown]
# ## 2.1. Setting up the architecture
# ![image.png](attachment:a7f99b0d-d488-424e-891d-ece8cb81da9d.png)
#
# We will be setting the layers as followed:
#
# - Hidden layer 1: 32 neurons, ReLU activation
# - Hidden layer 2: 32 neurons, ReLU activation
# - Output Layer: 1 neuron, Sigmoid activation
#
# Different activation function that can be applied:
# - Sigmoid Function (A function which ‘squeezes’ all the initial output to be between 0 and 1)
# - tanh Function (A function which ‘squeezes’ all the initial output to be between -1 and 1)
# - ReLU Function (If the initial output is negative, then output 0. If not, do nothing to the initial output)

# %%
# importing keras that will be used to set the architecture 
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# We will be setting the model layers

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)), #32 is the size of the first layer, & 10 referes to the 10 input features
    Dense(32, activation='relu'), #32 is the size of the first layer
    Dense(1, activation='sigmoid'), #1 neuron as output layer for the prediction
])

# %% [markdown]
# ## 2.2.  Configuring & Training the Model
#
# The architecture for the model has been set but we still need to configure the model. These configurations include:
# - what optimizer will be used such as SGD & Adam.
# - what lost function will be used? (first checking if it is for Probabilistic or regression losses) such as BinaryCrossentropy & CategoricalCressentropy.
# - what other metrics will like to be tracker such as Accuray & MeanSquaredError.
#
# In this section we will be conducting the followed steps:
# 1. Specify some hyper-parameters (the template)
# 2. Train on the training dataset (filling in the parameters)
# 3. Record the validation loss
# 4. Applying confusion matrix on the output
# 5. conclusion

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy', #chosen for our binary output
              metrics=['accuracy'])

# %% [markdown]
# Time to train the model

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 10ms/step - loss: 0.7069 - accuracy: 0.3004 - val_loss: 0.7012 - val_accuracy: 0.4247
# Epoch 2/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0
100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3064 - accuracy: 0.8855 - val_loss: 0.3124 - val_accuracy: 0.8676
# Epoch 91/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3062 - accuracy: 0.8855 - val_loss: 0.3110 - val_accuracy: 0.8676
# Epoch 92/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3043 - accuracy: 0.8875 - val_loss: 0.3098 - val_accuracy: 0.8721
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.8865 - val_loss: 0.3085 - val_accuracy: 0.8721
# Epoch 94/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3024 - accuracy: 0.8816 - val_loss: 0.3084 - val_accuracy: 0.8676
# Epoch 95/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3016 - accuracy: 0.8845 - val_loss: 0.3066 - val_accuracy: 0.8721
# Epoch 96/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.8855 - val_loss: 0.3068 - val_accuracy: 0.8676
# Epoch 97/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3002 - accuracy: 0.8826 - val_loss: 0.3061 - val_accuracy: 0.8676
# Epoch 98/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2996 - accuracy: 0.8855 - val_loss: 0.3046 - val_accuracy: 0.8721
# Epoch 99/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2986 - accuracy: 0.8826 - val_loss: 0.3038 - val_accuracy: 0.8721
# Epoch 100/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2976 - accuracy: 0.8855 - val_loss: 0.3019 - val_accuracy: 0.8813

# %% [markdown]
# Evaluating the model

# %%
model.evaluate(X_test, Y_test)
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2931 - accuracy: 0.8858
# [0.2930530607700348, 0.8858447670936584]

# %% [markdown]
# ### Summary of the model
# - setting up the architecture with keras. This included the input layer, 2 hidden layers and 1 output layer.
# - compiling the model by seeting the settings of the model (optimizer, loss function & metrics)
# - training the model and finding the best fit parameters with using the validation data.
# - evaluating the nodel on the test dataset.

# %% [markdown]
# ## 2.3. Visualizing Loss and Accuracy
# THis chapter will be focussed on visualizing the training loss and validation loss to see how our model trained.
# We will be looking how well our model performs and if we have overfitted.
# Overfitting occurs when the model has fitted so well to the training dataset that it has failed to generalize to unseen examples. This is characterized by a high dev (validation) loss and a low train loss, and can be addressed with regularization techniques.
# These techniques can be see as adding regularization, early stopping or dropout.

# %%
# Needed imports
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# Next we will be plotting the training accuracy and validation accuracy

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# the plot above shows the model's accuracy for the training and validation set

# %% [markdown]
# ## 2.4 Confusion Matrix

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
Y_pred = model.predict(X_test)
y_pred = np.round(Y_pred, 0).tolist()
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
confusion_matrix(Y_test, y_pred)
# Out:
# array([[ 92,  15],
#        [ 10, 102]], dtype=int64)

# %%
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       107
#            1       0.87      0.91      0.89       112
#
#     accuracy                           0.89       219
#    macro avg       0.89      0.89      0.89       219
# weighted avg       0.89      0.89      0.89       219

# %% [markdown]
# # 3. Hypertuning the model
# In this section we will be hypertuning the optimizer and loss function for the model to see if it will perform better or worse and why.

# %% [markdown]
# ## 3.1. Hypertuning the model optimizers
# In this chapter we will use the same steps for setting up the neural network but play around with the hyper paramters to see if we can get a better model by evaluating the loss and accuracy.
#
# In this section we will be training and hypertuning the model to find the best results. The steps will go as followed:
# 1. Specify some hyper-parameters (the template)
# 2. Train on the training dataset (filling in the parameters)
# 3. Applying confusion matrix on the output
# 4. Record the validation loss
# 5. Repeat Steps 1 to 3 with a different set of hyper-parameters (many times)
# 6. Conclusion

# %% [markdown]
# ### 3.1.1 Using Adam as optimizer
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.

# %% [markdown]
# <b>Neural Network Architecture</b>

# %%
model_2 = Sequential([
    Dense(32, activation='relu', input_shape=(10,)), #32 is the size of the first layer, & 10 referes to the 10 input features
    Dense(32, activation='relu'), #32 is the size of the first layer
    Dense(1, activation='sigmoid'), #1 neuron as output layer for the prediction
])

# %%
model_2.compile(optimizer='Adam',
              loss='binary_crossentropy', #chosen for our binary output
              metrics=['accuracy'])

# %% [markdown]
# <b>Training the Model</b>

# %%
hist_test_2 = model_2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 13ms/step - loss: 0.6777 - accuracy: 0.6115 - val_loss: 0.6619 - val_accuracy: 0.5297
# Epoch 2/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6291 - accuracy: 0.6830 - val_loss: 0.6102 - val_accuracy: 0.7945
# Epoch 3/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5709 - accuracy: 0.8229 - val_loss: 0.5488 - val_accuracy: 0.8128
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5003 - accuracy: 0.8395 - val_loss: 0.4702 - val_accuracy: 0.8402
# Epoch 5/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4299 - accuracy: 0.8542 - val_loss: 0.4049 - val_accuracy: 0.8539
# Epoch 6/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3766 - accuracy: 0.8669 - val_loss: 0.3662 - val_accuracy: 0.8584
# Epoch 7/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3485 - accuracy: 0.8650 - val_loss: 0.3427 - val_accuracy: 0.8584
# Epoch 8/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3330 - accuracy: 0.8591 - val_loss: 0.3326 - val_accuracy: 0.8584
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3253 - accuracy: 0.8669 - val_loss: 0.3254 - val_accuracy: 0.8630
# Epoch 10/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3132 - accuracy: 0.8728 - val_loss: 0.3139 - val_accuracy: 0.8630
# Epoch 11/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3084 - accuracy: 0.8728 - val_loss: 0.3129 - val_accuracy: 0.8584
# Epoch 12/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3003 - accuracy: 0.8767 - val_loss: 0.3036 - val_accuracy: 0.8630
# Epoch 13/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2952 - accuracy: 0.8796 - val_loss: 0.2975 - val_accuracy: 0.8676
# Epoch 14/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2907 - accuracy: 0.8806 - val_loss: 0.2957 - val_accuracy: 0.8584
# Epoch 15/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2866 - accuracy: 0.8816 - val_loss: 0.2908 - val_accuracy: 0.8721
# Epoch 16/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2832 - accuracy: 0.8865 - val_loss: 0.2883 - val_accuracy: 0.8676
# Epoch 17/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2785 - accuracy: 0.8845 - val_loss: 0.2805 - val_accuracy: 0.8676
# Epoch 18/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0
100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2379 - accuracy: 0.9012 - val_loss: 0.2544 - val_accuracy: 0.8721
# Epoch 46/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2362 - accuracy: 0.9002 - val_loss: 0.2309 - val_accuracy: 0.8995
# Epoch 47/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2310 - accuracy: 0.9061 - val_loss: 0.2275 - val_accuracy: 0.8995
# Epoch 48/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2301 - accuracy: 0.9002 - val_loss: 0.2350 - val_accuracy: 0.8858
# Epoch 49/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2290 - accuracy: 0.9022 - val_loss: 0.2364 - val_accuracy: 0.8904
# Epoch 50/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2297 - accuracy: 0.8953 - val_loss: 0.2285 - val_accuracy: 0.8995
# Epoch 51/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2302 - accuracy: 0.9022 - val_loss: 0.2252 - val_accuracy: 0.9041
# Epoch 52/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2275 - accuracy: 0.8992 - val_loss: 0.2239 - val_accuracy: 0.9041
# Epoch 53/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2307 - accuracy: 0.8982 - val_loss: 0.2253 - val_accuracy: 0.9132
# Epoch 54/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2277 - accuracy: 0.8973 - val_loss: 0.2217 - val_accuracy: 0.8995
# Epoch 55/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2282 - accuracy: 0.9041 - val_loss: 0.2256 - val_accuracy: 0.9178
# Epoch 56/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2360 - accuracy: 0.9002 - val_loss: 0.2216 - val_accuracy: 0.8995
# Epoch 57/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2274 - accuracy: 0.9041 - val_loss: 0.2211 - val_accuracy: 0.9132
# Epoch 58/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2244 - accuracy: 0.9041 - val_loss: 0.2273 - val_accuracy: 0.8995
# Epoch 59/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2240 - accuracy: 0.9002 - val_loss: 0.2192 - val_accuracy: 0.8995
# Epoch 60/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2233 - accuracy: 0.9051 - val_loss: 0.2299 - val_accuracy: 0.8995
# Epoch 61/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2251 - accuracy: 0.8992 - val_loss: 0.2236 - val_accuracy: 0.8995
# Epoch 62/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2231 - accuracy: 0.9031 - val_loss: 0.2177 - val_accuracy: 0.9087
# Epoch 63/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2225 - accuracy: 0.9080 - val_loss: 0.2200 - val_accuracy: 0.8995
# Epoch 64/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2229 - accuracy: 0.8982 - val_loss: 0.2182 - val_accuracy: 0.8950
# Epoch 65/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2236 - accuracy: 0.9031 - val_loss: 0.2174 - val_accuracy: 0.9041
# Epoch 66/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2264 - accuracy: 0.9022 - val_loss: 0.2454 - val_accuracy: 0.8813
# Epoch 67/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2316 - accuracy: 0.8933 - val_loss: 0.2193 - val_accuracy: 0.8995
# Epoch 68/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2230 - accuracy: 0.9110 - val_loss: 0.2374 - val_accuracy: 0.8904
# Epoch 69/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2173 - accuracy: 0.9041 - val_loss: 0.2203 - val_accuracy: 0.9269
# Epoch 70/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2221 - accuracy: 0.9031 - val_loss: 0.2221 - val_accuracy: 0.8995
# Epoch 71/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2229 - accuracy: 0.9061 - val_loss: 0.2204 - val_accuracy: 0.8995
# Epoch 72/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2202 - accuracy: 0.9031 - val_loss: 0.2226 - val_accuracy: 0.9087
# Epoch 73/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2197 - accuracy: 0.9051 - val_loss: 0.2414 - val_accuracy: 0.8995
# Epoch 74/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2217 - accuracy: 0.9051 - val_loss: 0.2373 - val_accuracy: 0.8904
# Epoch 75/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2224 - accuracy: 0.9041 - val_loss: 0.2129 - val_accuracy: 0.8995
# Epoch 76/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2216 - accuracy: 0.9119 - val_loss: 0.2358 - val_accuracy: 0.8950
# Epoch 77/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2195 - accuracy: 0.9051 - val_loss: 0.2247 - val_accuracy: 0.9041
# Epoch 78/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2181 - accuracy: 0.9051 - val_loss: 0.2203 - val_accuracy: 0.9041
# Epoch 79/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9080 - val_loss: 0.2246 - val_accuracy: 0.9041
# Epoch 80/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2173 - accuracy: 0.9070 - val_loss: 0.2306 - val_accuracy: 0.8995
# Epoch 81/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2173 - accuracy: 0.9070 - val_loss: 0.2100 - val_accuracy: 0.9132
# Epoch 82/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2217 - accuracy: 0.9031 - val_loss: 0.2250 - val_accuracy: 0.9041
# Epoch 83/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2218 - accuracy: 0.9031 - val_loss: 0.2120 - val_accuracy: 0.9087
# Epoch 84/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2167 - accuracy: 0.9070 - val_loss: 0.2186 - val_accuracy: 0.9087
# Epoch 85/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2191 - accuracy: 0.9002 - val_loss: 0.2104 - val_accuracy: 0.9087
# Epoch 86/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2198 - accuracy: 0.9031 - val_loss: 0.2097 - val_accuracy: 0.9178
# Epoch 87/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.2190 - accuracy: 0.9031 - val_loss: 0.2075 - val_accuracy: 0.9087
# Epoch 88/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2159 - accuracy: 0.9051 - val_loss: 0.2163 - val_accuracy: 0.9087
# Epoch 89/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2147 - accuracy: 0.9041 - val_loss: 0.2073 - val_accuracy: 0.9132
# Epoch 90/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2132 - accuracy: 0.9031 - val_loss: 0.2044 - val_accuracy: 0.9269
# Epoch 91/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2148 - accuracy: 0.9061 - val_loss: 0.2041 - val_accuracy: 0.9178
# Epoch 92/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2135 - accuracy: 0.9031 - val_loss: 0.2061 - val_accuracy: 0.9132
# Epoch 93/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9041 - val_loss: 0.2130 - val_accuracy: 0.9087
# Epoch 94/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2195 - accuracy: 0.9061 - val_loss: 0.2286 - val_accuracy: 0.9041
# Epoch 95/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2224 - accuracy: 0.8973 - val_loss: 0.2134 - val_accuracy: 0.9087
# Epoch 96/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2129 - accuracy: 0.9041 - val_loss: 0.2022 - val_accuracy: 0.9224
# Epoch 97/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2125 - accuracy: 0.9061 - val_loss: 0.2018 - val_accuracy: 0.9269
# Epoch 98/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2129 - accuracy: 0.9022 - val_loss: 0.2025 - val_accuracy: 0.9178
# Epoch 99/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2224 - accuracy: 0.9002 - val_loss: 0.2044 - val_accuracy: 0.9132
# Epoch 100/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2130 - accuracy: 0.9061 - val_loss: 0.2027 - val_accuracy: 0.9087

# %% [markdown]
# <b>Evaluating the Model</b>

# %%
model_2.evaluate(X_test, Y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2355 - accuracy: 0.8995
# [0.23546208441257477, 0.8995434045791626]

# %% [markdown]
# <b>Confusion Matrix</b>

# %%
Y_pred = model_2.predict(X_test).round()
y_pred = np.round(Y_pred, 0).tolist()
confusion_matrix(Y_test, y_pred)
# Out:
# 7/7 [==============================] - 0s 2ms/step
# array([[ 94,  13],
#        [  9, 103]], dtype=int64)

# %%
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       107
#            1       0.89      0.92      0.90       112
#
#     accuracy                           0.90       219
#    macro avg       0.90      0.90      0.90       219
# weighted avg       0.90      0.90      0.90       219

# %% [markdown]
# <b>Visualizing Loss</b>

# %%
plt.plot(hist_test_2.history['loss'])
plt.plot(hist_test_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# <b>Visualizing Accuracy</b>

# %%
plt.plot(hist_test_2.history['accuracy'])
plt.plot(hist_test_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# ### 3.1.2 Using RMSprop as optimizer
# The gist of RMSprop is to:
# - Maintain a moving (discounted) average of the square of gradients
# - Divide the gradient by the root of this average

# %% [markdown]
# <b>Neural Network Architecture</b>

# %%
model_3 = Sequential([
    Dense(32, activation='relu', input_shape=(10,)), #32 is the size of the first layer, & 10 referes to the 10 input features
    Dense(32, activation='relu'), #32 is the size of the first layer
    Dense(1, activation='sigmoid'), #1 neuron as output layer for the prediction
])

# %%
model_3.compile(optimizer='RMSprop',
              loss='binary_crossentropy', #chosen for our binary output
              metrics=['accuracy'])

# %% [markdown]
# <b>Training the Model</b>

# %%
hist_test_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 13ms/step - loss: 0.6427 - accuracy: 0.7339 - val_loss: 0.6109 - val_accuracy: 0.7443
# Epoch 2/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5670 - accuracy: 0.7896 - val_loss: 0.5443 - val_accuracy: 0.7900
# Epoch 3/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.8249 - val_loss: 0.4817 - val_accuracy: 0.8447
# Epoch 4/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4536 - accuracy: 0.8386 - val_loss: 0.4371 - val_accuracy: 0.8447
# Epoch 5/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4161 - accuracy: 0.8483 - val_loss: 0.4068 - val_accuracy: 0.8493
# Epoch 6/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3924 - accuracy: 0.8513 - val_loss: 0.3815 - val_accuracy: 0.8721
# Epoch 7/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3751 - accuracy: 0.8650 - val_loss: 0.3746 - val_accuracy: 0.8539
# Epoch 8/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3626 - accuracy: 0.8581 - val_loss: 0.3571 - val_accuracy: 0.8584
# Epoch 9/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3526 - accuracy: 0.8611 - val_loss: 0.3481 - val_accuracy: 0.8630
# Epoch 10/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3479 - accuracy: 0.8659 - val_loss: 0.3440 - val_accuracy: 0.8630
# Epoch 11/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3415 - accuracy: 0.8601 - val_loss: 0.3391 - val_accuracy: 0.8630
# Epoch 12/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0
100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2311 - accuracy: 0.8943 - val_loss: 0.2391 - val_accuracy: 0.8858
# Epoch 73/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2293 - accuracy: 0.9070 - val_loss: 0.2345 - val_accuracy: 0.8904
# Epoch 74/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.9041 - val_loss: 0.2390 - val_accuracy: 0.9224
# Epoch 75/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2284 - accuracy: 0.8973 - val_loss: 0.2292 - val_accuracy: 0.8950
# Epoch 76/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2251 - accuracy: 0.9061 - val_loss: 0.2509 - val_accuracy: 0.8767
# Epoch 77/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2265 - accuracy: 0.9002 - val_loss: 0.2395 - val_accuracy: 0.8767
# Epoch 78/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2219 - accuracy: 0.9061 - val_loss: 0.2245 - val_accuracy: 0.9132
# Epoch 79/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2264 - accuracy: 0.9002 - val_loss: 0.2239 - val_accuracy: 0.9087
# Epoch 80/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2277 - accuracy: 0.9002 - val_loss: 0.2387 - val_accuracy: 0.8904
# Epoch 81/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2279 - accuracy: 0.8982 - val_loss: 0.2347 - val_accuracy: 0.8950
# Epoch 82/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.9012 - val_loss: 0.2228 - val_accuracy: 0.9132
# Epoch 83/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2234 - accuracy: 0.9002 - val_loss: 0.2264 - val_accuracy: 0.8950
# Epoch 84/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2268 - accuracy: 0.8992 - val_loss: 0.2232 - val_accuracy: 0.9132
# Epoch 85/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2252 - accuracy: 0.9002 - val_loss: 0.2249 - val_accuracy: 0.9041
# Epoch 86/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.9041 - val_loss: 0.2233 - val_accuracy: 0.9132
# Epoch 87/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2256 - accuracy: 0.9041 - val_loss: 0.2242 - val_accuracy: 0.9041
# Epoch 88/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2216 - accuracy: 0.9012 - val_loss: 0.2369 - val_accuracy: 0.8950
# Epoch 89/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2214 - accuracy: 0.9022 - val_loss: 0.2500 - val_accuracy: 0.8767
# Epoch 90/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2204 - accuracy: 0.9051 - val_loss: 0.2231 - val_accuracy: 0.9041
# Epoch 91/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2223 - accuracy: 0.8992 - val_loss: 0.2233 - val_accuracy: 0.9041
# Epoch 92/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2213 - accuracy: 0.9041 - val_loss: 0.2432 - val_accuracy: 0.8813
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9100 - val_loss: 0.2208 - val_accuracy: 0.9132
# Epoch 94/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2237 - accuracy: 0.9031 - val_loss: 0.2205 - val_accuracy: 0.9087
# Epoch 95/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2198 - accuracy: 0.9070 - val_loss: 0.2327 - val_accuracy: 0.8904
# Epoch 96/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2234 - accuracy: 0.9022 - val_loss: 0.2217 - val_accuracy: 0.9041
# Epoch 97/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2199 - accuracy: 0.9051 - val_loss: 0.2200 - val_accuracy: 0.9041
# Epoch 98/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2190 - accuracy: 0.9041 - val_loss: 0.2212 - val_accuracy: 0.9041
# Epoch 99/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2194 - accuracy: 0.9041 - val_loss: 0.2198 - val_accuracy: 0.9087
# Epoch 100/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2194 - accuracy: 0.9100 - val_loss: 0.2183 - val_accuracy: 0.9132

# %% [markdown]
# <b>Evaluating the Model</b>

# %%
model_3.evaluate(X_test, Y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2284 - accuracy: 0.8995
# [0.22835345566272736, 0.8995434045791626]

# %% [markdown]
# <b>Confusion Matrix</b>

# %%
Y_pred = model_3.predict(X_test).round()
y_pred = np.round(Y_pred, 0).tolist()
confusion_matrix(Y_test, y_pred)
# Out:
# 7/7 [==============================] - 0s 3ms/step
# array([[ 96,  11],
#        [ 11, 101]], dtype=int64)

# %%
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       107
#            1       0.90      0.90      0.90       112
#
#     accuracy                           0.90       219
#    macro avg       0.90      0.90      0.90       219
# weighted avg       0.90      0.90      0.90       219

# %% [markdown]
# <b>Visualizing Loss</b>

# %%
plt.plot(hist_test_3.history['loss'])
plt.plot(hist_test_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# <b>Visualizing Accuracy</b>

# %%
plt.plot(hist_test_3.history['accuracy'])
plt.plot(hist_test_3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# ### 3.1.3. Conclusion
# We have tried out 2 different optimizers (Adam & RMSprop) to compare to the SGD optimizer.
# Based on the finding, all three give a similiar overal accuracy with the RMSprop being the highest and for the loss section are they all again quite even with the Adam optimizer having the lowest loss.
# SGD is well known to perform better than Adam with also outperformances on the training data but in our case we had a slight better output with Adam for our dataset and how the model is set up.
# Lastly, Adam does perform better but if we visualize the loss on the plots compared to SGD, we see that SGD has a even distribution comparing both lines whereas Adam's plots differentiate for each epoch.

# %% [markdown]
# ## 3.2. Hypertuning the model loss functions
# In this chapter we will use the same steps for setting up the neural network but play around with the hyper paramters to see if we can get a better model by evaluating the loss and accuracy.
#
# We will be following 4 steps:
# 1. Specify some hyper-parameters (the template)
# 2. Train on the training dataset (filling in the parameters)
# 3. Record the validation loss
# 4. Repeat Steps 1 to 3 with a different set of hyper-parameters (many times)

# %% [markdown]
# ### 3.2.1 Using CategoricalHinge as loss
# Computes the categorical hinge loss between y_true & y_pred.

# %% [markdown]
# <b>Neural Network Architecture</b>

# %%
model_4 = Sequential([
    Dense(32, activation='relu', input_shape=(10,)), #32 is the size of the first layer, & 10 referes to the 10 input features
    Dense(32, activation='relu'), #32 is the size of the first layer
    Dense(1, activation='sigmoid'), #1 neuron as output layer for the prediction
])

# %%
model_4.compile(optimizer='sgd',
              loss='CategoricalHinge', #chosen for our binary output
              metrics=['accuracy'])

# %% [markdown]
# <b>Training the Model</b>

# %%
hist_test_4 = model_4.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 10ms/step - loss: 0.9962 - accuracy: 0.5039 - val_loss: 1.0399 - val_accuracy: 0.4612
# Epoch 2/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9942 - accuracy: 0.5049 - val_loss: 1.0384 - val_accuracy: 0.4612
# Epoch 3/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9923 - accuracy: 0.5039 - val_loss: 1.0370 - val_accuracy: 0.4612
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9904 - accuracy: 0.5039 - val_loss: 1.0357 - val_accuracy: 0.4612
# Epoch 5/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9885 - accuracy: 0.5039 - val_loss: 1.0342 - val_accuracy: 0.4612
# Epoch 6/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9866 - accuracy: 0.5039 - val_loss: 1.0328 - val_accuracy: 0.4612
# Epoch 7/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9846 - accuracy: 0.5039 - val_loss: 1.0313 - val_accuracy: 0.4612
# Epoch 8/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9825 - accuracy: 0.5039 - val_loss: 1.0297 - val_accuracy: 0.4612
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9803 - accuracy: 0.5039 - val_loss: 1.0280 - val_accuracy: 0.4612
# Epoch 10/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9781 - accuracy: 0.5039 - val_loss: 1.0262 - val_accuracy: 0.4612
# Epoch 11/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9758 - accuracy: 0.5039 - val_loss: 1.0245 - val_accuracy: 0.4612
# Epoch 12/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9735 - accuracy: 0.5039 - val_loss: 1.0228 - val_accuracy: 0.4612
# Epoch 13/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9712 - accuracy: 0.5039 - val_loss: 1.0211 - val_accuracy: 0.4612
# Epoch 14/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9690 - accuracy: 0.5039 - val_loss: 1.0194 - val_accuracy: 0.4612
# Epoch 15/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9668 - accuracy: 0.5039 - val_loss: 1.0177 - val_accuracy: 0.4612
# Epoch 16/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9647 - accuracy: 0.5039 - val_loss: 1.0161 - val_accuracy: 0.4612
# Epoch 17/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9625 - accuracy: 0.5039 - val_loss: 1.0144 - val_accuracy: 0.4612
# Epoch 18/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9604 - accuracy: 0.5039 - val_loss: 1.0128 - val_accuracy: 0.4612
# Epoch 19/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9584 - accuracy: 0.5049 - val_loss: 1.0111 - val_accuracy: 0.4612
# Epoch 20/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9563 - accuracy: 0.5049 - val_loss: 1.0095 - val_accuracy: 0.4612
# Epoch 21/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9542 - accuracy: 0.5049 - val_loss: 1.0077 - val_accuracy: 0.4658
# Epoch 22/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9521 - accuracy: 0.5049 - val_loss: 1.0060 - val_accuracy: 0.4658
# Epoch 23/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9500 - accuracy: 0.5049 - val_loss: 1.0042 - val_accuracy: 0.4658
# Epoch 24/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9479 - accuracy: 0.5049 - val_loss: 1.0023 - val_accuracy: 0.4658
# Epoch 25/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9458 - accuracy: 0.5049 - val_loss: 1.0003 - val_accuracy: 0.4658
# Epoch 26/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9436 - accuracy: 0.5049 - val_loss: 0.9983 - val_accuracy: 0.4658
# Epoch 27/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9414 - accuracy: 0.5049 - val_loss: 0.9962 - val_accuracy: 0.4658
# Epoch 28/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9390 - accuracy: 0.5059 - val_loss: 0.9939 - val_accuracy: 0.4658
# Epoch 29/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9367 - accuracy: 0.5059 - val_loss: 0.9916 - val_accuracy: 0.4658
# Epoch 30/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9342 - accuracy: 0.5059 - val_loss: 0.9891 - val_accuracy: 0.4658
# Epoch 31/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9318 - accuracy: 0.5068 - val_loss: 0.9865 - val_accuracy: 0.4658
# Epoch 32/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9291 - accuracy: 0.5147 - val_loss: 0.9839 - val_accuracy: 0.4749
# Epoch 33/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9264 - accuracy: 0.5186 - val_loss: 0.9810 - val_accuracy: 0.4795
# Epoch 34/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9236 - accuracy: 0.5274 - val_loss: 0.9780 - val_accuracy: 0.4886
# Epoch 35/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9207 - accuracy: 0.5323 - val_loss: 0.9748 - val_accuracy: 0.4977
# Epoch 36/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0
100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6947 - accuracy: 0.8659 - val_loss: 0.7403 - val_accuracy: 0.8813
# Epoch 95/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6928 - accuracy: 0.8630 - val_loss: 0.7385 - val_accuracy: 0.8813
# Epoch 96/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6910 - accuracy: 0.8640 - val_loss: 0.7368 - val_accuracy: 0.8767
# Epoch 97/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6894 - accuracy: 0.8640 - val_loss: 0.7352 - val_accuracy: 0.8767
# Epoch 98/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.8659 - val_loss: 0.7337 - val_accuracy: 0.8813
# Epoch 99/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6863 - accuracy: 0.8650 - val_loss: 0.7322 - val_accuracy: 0.8767
# Epoch 100/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6848 - accuracy: 0.8679 - val_loss: 0.7308 - val_accuracy: 0.8813

# %% [markdown]
# <b>Evaluating the Model</b>

# %%
model_4.evaluate(X_test, Y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6821 - accuracy: 0.8767
# [0.6820817589759827, 0.8767123222351074]

# %% [markdown]
# <b>Confusion Matrix</b>

# %%
Y_pred = model_4.predict(X_test).round()
y_pred = np.round(Y_pred, 0).tolist()
confusion_matrix(Y_test, y_pred)
# Out:
# 7/7 [==============================] - 0s 3ms/step
# array([[ 86,  21],
#        [  6, 106]], dtype=int64)

# %%
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       107
#            1       0.90      0.90      0.90       112
#
#     accuracy                           0.90       219
#    macro avg       0.90      0.90      0.90       219
# weighted avg       0.90      0.90      0.90       219

# %% [markdown]
# <b>Visualizing Loss</b>

# %%
plt.plot(hist_test_4.history['loss'])
plt.plot(hist_test_4.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# <b>Visualizing Accuracy</b>

# %%
plt.plot(hist_test_4.history['accuracy'])
plt.plot(hist_test_4.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# ### 3.2.2 Using poisson as loss
# Computes the Poisson loss between y_true and y_pred.

# %% [markdown]
# <b>Neural Network Architecture</b>

# %%
model_5 = Sequential([
    Dense(32, activation='relu', input_shape=(10,)), #32 is the size of the first layer, & 10 referes to the 10 input features
    Dense(32, activation='relu'), #32 is the size of the first layer
    Dense(1, activation='sigmoid'), #1 neuron as output layer for the prediction
])

# %%
model_5.compile(optimizer='sgd',
              loss='poisson', #chosen for our binary output
              metrics=['accuracy'])

# %% [markdown]
# <b>Training the Model</b>

# %%
hist_test_5 = model_5.fit(X_train, Y_train,
          batch_size=32, epochs=200,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/200
# 32/32 [==============================] - 1s 12ms/step - loss: 0.8478 - accuracy: 0.6174 - val_loss: 0.8175 - val_accuracy: 0.6849
# Epoch 2/200
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8464 - accuracy: 0.6869 - val_loss: 0.8164 - val_accuracy: 0.7123
# Epoch 3/200
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8450 - accuracy: 0.7084 - val_loss: 0.8153 - val_accuracy: 0.7306
# Epoch 4/200
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6346 - accuracy: 0.8914 - val_loss: 0.5964 - val_accuracy: 0.8858
# Epoch 200/200
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6345 - accuracy: 0.8904 - val_loss: 0.5962 - val_accuracy: 0.8858

# %% [markdown]
# <b>Evaluating the Model</b>

# %%
model_5.evaluate(X_test, Y_test)
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6454 - accuracy: 0.8858
# [0.6454096436500549, 0.8858447670936584]

# %% [markdown]
# <b>Confusion Matrix</b>

# %%
Y_pred = model_5.predict(X_test).round()
y_pred = np.round(Y_pred, 0).tolist()
confusion_matrix(Y_test, y_pred)
# Out:
# 7/7 [==============================] - 0s 3ms/step
# array([[ 91,  16],
#        [  9, 103]], dtype=int64)

# %%
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       107
#            1       0.90      0.90      0.90       112
#
#     accuracy                           0.90       219
#    macro avg       0.90      0.90      0.90       219
# weighted avg       0.90      0.90      0.90       219

# %% [markdown]
# <b>Visualizing Loss</b>

# %%
plt.plot(hist_test_5.history['loss'])
plt.plot(hist_test_5.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# <b>Visualizing Accuracy</b>

# %%
plt.plot(hist_test_5.history['accuracy'])
plt.plot(hist_test_5.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# ### 3.2.3. Conclusion
# We have tried out 2 different loss function to compare to the Binary Crossentropy function which are the poisson and categorical hinge functions.
# Based on the finding, all three give a similiar overal accuracy but comparing the losses which they are, the Binary Crossentropy function performs the best out of the 3 for this data.

# %% [markdown]
# ## 3.3. Conclusion on Hypertuning the model
# Based on hypertuning the loss function and optimizers we can conclude that the original set hyperparamaters used (Binary Crossentropy & SGD) were the best in comparison to the hyperparameters tried onto the model.
# The results overall with hypertuning the model came close but were the best ones being the orginal set hyper parameters which we have concluded.

# %% [markdown]
# # Reflection
# To reflect on this exercise, I have learned how to apply my knowledge and skills in creating a neural network on a random dataset. Although I encountered some difficulties, such as applying the confusion matrix and optimizers, I persisted and eventually gained a better understanding of these concepts.
#
# Additionally, I gained knowledge on new techniques such as Regularization, Early Stopping & Dropout to prevent overfitting of the neural network. Although my neural network in this exercise did not suffer from overfitting, I now have a better understanding of how to address this issue if it were to occur in the future.
#
# Overall, this exercise has provided me with valuable experience and knowledge that I can apply in future projects involving neural networks and machine learning.

# %% [markdown]
# # Sources
# data source that the project is based on: https://www.kaggle.com/c/zillow-prize-1/data
#
# reformed data source: https://drive.google.com/file/d/1GfvKA0qznNVknghV4botnNxyH-KvODOC/view
#
# tutorial/code used to help: https://www.freecodecamp.org/news/how-to-build-your-first-neural-network-to-predict-house-prices-with-keras-f8db83049159/
#
# Helped to set the prediction of the neural network to the right format tot use with also sigmoid included: https://stackoverflow.com/questions/73199505/confusion-matrix-for-binary-classification-with-nn
#
# Steps used for applying the confusion matrix: https://www.jcchouinard.com/confusion-matrix-in-scikit-learn/
